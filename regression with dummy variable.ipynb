# %%
import pandas as mypd

# %%
import matplotlib.pyplot as myplot 
from pandas.tools.plotting import scatter_matrix
from statsmodels.formula.api import ols
from statsmodels.stats.anova import anova_lm

# %%
mydata = mypd.read_csv("/Users/harisuriya/Desktop/mlworkshop/Data/Travel_dummy_Reg.csv")

# %%
mydata
# Out:
#     SL No  Gender  Income  Attitude
# 0       1       1       1         2
# 1       2       1       1         3
# 2       3       1       1         1
# 3       4       1       1         1
# 4       5       1       1         2
# 5       6       1       2         4
# 6       7       1       2         5
# 7       8       1       2         5
# 8       9       1       2         6
# 9      10       1       2         6
# 10     11       1       3         8
# 11     12       1       3         9
# 12     13       1       3         8
# 13     14       1       3         7
# 14     15       1       3         7
# 15     16       2       1         1
# 16     17       2       1         1
# 17     18       2       1         2
# 18     19       2       1         2
# 19     20       2       1         1
# 20     21       2       2         3
# 21     22       2       2         4
# 22     23       2       2         5
# 23     24       2       2         3
# 24     25       2       2         3
# 25     26       2       3         5
# 26     27       2       3         5
# 27     28       2       3         5
# 28     29       2       3         4
# 29     30       2       3         6

# %%
mydata
# Out:
#     SL No  Gender  Income  Attitude
# 0       1       1       1         2
# 1       2       1       1         3
# 2       3       1       1         1
# 3       4       1       1         1
# 4       5       1       1         2
# 5       6       1       2         4
# 6       7       1       2         5
# 7       8       1       2         5
# 8       9       1       2         6
# 9      10       1       2         6
# 10     11       1       3         8
# 11     12       1       3         9
# 12     13       1       3         8
# 13     14       1       3         7
# 14     15       1       3         7
# 15     16       2       1         1
# 16     17       2       1         1
# 17     18       2       1         2
# 18     19       2       1         2
# 19     20       2       1         1
# 20     21       2       2         3
# 21     22       2       2         4
# 22     23       2       2         5
# 23     24       2       2         3
# 24     25       2       2         3
# 25     26       2       3         5
# 26     27       2       3         5
# 27     28       2       3         5
# 28     29       2       3         4
# 29     30       2       3         6

# %%
scatter_matrix(mydata)

myplot.show()
# Out:
# /Users/harisuriya/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: 'pandas.tools.plotting.scatter_matrix' is deprecated, import 'pandas.plotting.scatter_matrix' instead.
#   """Entry point for launching an IPython kernel.

# %%
gender = mydata.Gender
income = mydata.Income
attitude = mydata.Attitude

# %%
mydata.boxplot(column = 'Attitude', by = 'Gender')
myplot.show()

# %%
mydata.boxplot(column = 'Attitude', by = 'Income')
myplot.show()

# %%
gender = mydata.Gender
income = mydata.Income
attitude = mydata.Attitude

# %%
mymodel = ols('attitude ~ C(gender) + C(income)', mydata).fit()
mymodel.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               attitude   R-squared:                       0.860
# Model:                            OLS   Adj. R-squared:                  0.844
# Method:                 Least Squares   F-statistic:                     53.37
# Date:                Tue, 26 Jun 2018   Prob (F-statistic):           3.02e-11
# Time:                        00:59:16   Log-Likelihood:                -37.916
# No. Observations:                  30   AIC:                             83.83
# Df Residuals:                      26   BIC:                             89.44
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Intercept          2.4000      0.336      7.145      0.000       1.710       3.090
# C(gender)[T.2]    -1.6000      0.336     -4.763      0.000      -2.290      -0.910
# C(income)[T.2]     2.8000      0.411      6.806      0.000       1.954       3.646
# C(income)[T.3]     4.8000      0.411     11.668      0.000       3.954       5.646
# ==============================================================================
# Omnibus:                        0.521   Durbin-Watson:                   1.156
# Prob(Omnibus):                  0.771   Jarque-Bera (JB):                0.615
# Skew:                           0.089   Prob(JB):                        0.735
# Kurtosis:                       2.322   Cond. No.                         4.22
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# """

# %% [markdown]
# attitude=2.4-1.6gender2+2.8income2+4.8income3

# %%
pred=mymodel.predict()

# %%
pred
# Out:
# array([ 2.4,  2.4,  2.4,  2.4,  2.4,  5.2,  5.2,  5.2,  5.2,  5.2,  7.2,
#         7.2,  7.2,  7.2,  7.2,  0.8,  0.8,  0.8,  0.8,  0.8,  3.6,  3.6,
#         3.6,  3.6,  3.6,  5.6,  5.6,  5.6,  5.6,  5.6])

# %% [markdown]
# residual = actual value - predicted value

# %%
res=attitude-pred

# %%
res
# Out:
# 0    -0.4
# 1     0.6
# 2    -1.4
# 3    -1.4
# 4    -0.4
# 5    -1.2
# 6    -0.2
# 7    -0.2
# 8     0.8
# 9     0.8
# 10    0.8
# 11    1.8
# 12    0.8
# 13   -0.2
# 14   -0.2
# 15    0.2
# 16    0.2
# 17    1.2
# 18    1.2
# 19    0.2
# 20   -0.6
# 21    0.4
# 22    1.4
# 23   -0.6
# 24   -0.6
# 25   -0.6
# 26   -0.6
# 27   -0.6
# 28   -1.6
# 29    0.4
# Name: Attitude, dtype: float64

# %%
from scipy import stats
stats.probplot(res,plot=myplot)
myplot.show()

# %%
myplot.scatter(pred,res)
myplot.show()
